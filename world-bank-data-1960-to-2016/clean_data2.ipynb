# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load 
file_to_load = "fertility_rate.csv"

# Read Purchasing File and store into Pandas data frame
fertility_data = pd.read_csv(file_to_load)
fertility_data.head()
# Out:
#   Country Name Country Code                            Indicator Name  \
# 0        Aruba          ABW  Fertility rate, total (births per woman)
# 1  Afghanistan          AFG  Fertility rate, total (births per woman)
# 2       Angola          AGO  Fertility rate, total (births per woman)
# 3      Albania          ALB  Fertility rate, total (births per woman)
# 4      Andorra          AND  Fertility rate, total (births per woman)
#
#    Indicator Code   1960   1961   1962   1963   1964   1965  ...   2007  \
# 0  SP.DYN.TFRT.IN  4.820  4.655  4.471  4.271  4.059  3.842  ...  1.763
# 1  SP.DYN.TFRT.IN  7.450  7.450  7.450  7.450  7.450  7.450  ...  6.460
# 2  SP.DYN.TFRT.IN  7.478  7.524  7.563  7.592  7.611  7.619  ...  6.368
# 3  SP.DYN.TFRT.IN  6.489  6.401  6.282  6.133  5.960  5.773  ...  1.668
# 4  SP.DYN.TFRT.IN    NaN    NaN    NaN    NaN    NaN    NaN  ...  1.180
#
#     2008   2009   2010   2011   2012   2013   2014   2015   2016
# ...

# %%
fertility_data=fertility_data.drop(['Indicator Name','Indicator Code'], axis=1)
fertility_data.head()
# Out:
#   Country Name Country Code   1960   1961   1962   1963   1964   1965   1966  \
# 0        Aruba          ABW  4.820  4.655  4.471  4.271  4.059  3.842  3.625
# 1  Afghanistan          AFG  7.450  7.450  7.450  7.450  7.450  7.450  7.450
# 2       Angola          AGO  7.478  7.524  7.563  7.592  7.611  7.619  7.618
# 3      Albania          ALB  6.489  6.401  6.282  6.133  5.960  5.773  5.581
# 4      Andorra          AND    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#     1967  ...   2007   2008   2009   2010   2011   2012   2013   2014   2015  \
# 0  3.417  ...  1.763  1.764  1.769  1.776  1.783  1.791  1.796  1.800  1.801
# 1  7.450  ...  6.460  6.254  6.038  5.816  5.595  5.380  5.174  4.981  4.802
# 2  7.613  ...  6.368  6.307  6.238  6.162  6.082  6.000  5.920  5.841  5.766
# 3  5.394  ...  1.668  1.650  1.646  1.653  1.668  1.685  1.700  1.710  1.714
# 4    NaN  ...  1.180  1.250  1.190  1.270    NaN    NaN    NaN    NaN    NaN
#
#     2016
# 0  1.800
# 1  4.635
# ...

# %%
# File to Load 
file_to_load = "data_ori.csv"

# Read Purchasing File and store into Pandas data frame
country_data = pd.read_csv(file_to_load)
country_data.head()
# Out:
#    country  birth code  region   lat  long  id
# 0    Niger   49.7  NER  Africa  16.0   8.0   1
# 1     Mali   47.1  MLI  Africa  17.0  -4.0   2
# 2     Chad   45.9  TCD  Africa  15.0  19.0   3
# 3  Burundi   44.7  BUR  Africa  -3.5  30.0   4
# 4   Angola   44.1  AGO  Africa -12.5  18.5   5

# %%
country_data.rename(columns=
                    {'code':'Country Code'},
                    inplace = True
                )
country_data.head()
# Out:
#    country  birth Country Code  region   lat  long  id
# 0    Niger   49.7          NER  Africa  16.0   8.0   1
# 1     Mali   47.1          MLI  Africa  17.0  -4.0   2
# 2     Chad   45.9          TCD  Africa  15.0  19.0   3
# 3  Burundi   44.7          BUR  Africa  -3.5  30.0   4
# 4   Angola   44.1          AGO  Africa -12.5  18.5   5

# %%
fertility_country = pd.merge(left=fertility_data,right=country_data, how='left', left_on='Country Code', right_on='Country Code')
fertility_country.head()
# Out:
#   Country Name Country Code   1960   1961   1962   1963   1964   1965   1966  \
# 0        Aruba          ABW  4.820  4.655  4.471  4.271  4.059  3.842  3.625
# 1  Afghanistan          AFG  7.450  7.450  7.450  7.450  7.450  7.450  7.450
# 2       Angola          AGO  7.478  7.524  7.563  7.592  7.611  7.619  7.618
# 3      Albania          ALB  6.489  6.401  6.282  6.133  5.960  5.773  5.581
# 4      Andorra          AND    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#     1967  ...   2013   2014   2015   2016      country  birth  region   lat  \
# 0  3.417  ...  1.796  1.800  1.801  1.800          NaN    NaN     NaN   NaN
# 1  7.450  ...  5.174  4.981  4.802  4.635  Afghanistan   34.1    Asia  33.0
# 2  7.613  ...  5.920  5.841  5.766  5.694       Angola   44.1  Africa -12.5
# 3  5.394  ...  1.700  1.710  1.714  1.713      Albania   12.9  Europe  41.0
# 4    NaN  ...    NaN    NaN    NaN    NaN      Andorra    8.9  Europe  42.5
#
#    long     id
# 0   NaN    NaN
# ...

# %%
fertility_df = fertility_country[['Country Name','country','2016','Country Code','region','lat','long']]
fertility_df
# Out:
#                                           Country Name  \
# 0                                                Aruba
# 1                                          Afghanistan
# 2                                               Angola
# 3                                              Albania
# 4                                              Andorra
# 5                                           Arab World
# 6                                 United Arab Emirates
# 7                                            Argentina
# 8                                              Armenia
# 9                                       American Samoa
# 10                                 Antigua and Barbuda
# 11                                           Australia
# 12                                             Austria
# 13                                          Azerbaijan
# 14                                             Burundi
# 15                                             Belgium
# ...

# %%
fertility_df.index = np.arange(1, len(fertility_df) + 1)
fertility_df.head()
# Out:
#   Country Name      country   2016 Country Code  region   lat  long
# 1        Aruba          NaN  1.800          ABW     NaN   NaN   NaN
# 2  Afghanistan  Afghanistan  4.635          AFG    Asia  33.0  65.0
# 3       Angola       Angola  5.694          AGO  Africa -12.5  18.5
# 4      Albania      Albania  1.713          ALB  Europe  41.0  20.0
# 5      Andorra      Andorra    NaN          AND  Europe  42.5   1.6

# %%
fertility_df.index.name = 'New ID'
fertility_df.head()
# Out:
#        Country Name      country   2016 Country Code  region   lat  long
# New ID
# 1             Aruba          NaN  1.800          ABW     NaN   NaN   NaN
# 2       Afghanistan  Afghanistan  4.635          AFG    Asia  33.0  65.0
# 3            Angola       Angola  5.694          AGO  Africa -12.5  18.5
# 4           Albania      Albania  1.713          ALB  Europe  41.0  20.0
# 5           Andorra      Andorra    NaN          AND  Europe  42.5   1.6

# %%
fertility_df.loc[:,'2016'] *= 4
fertility_df
# Out:
#                                              Country Name  \
# New ID
# 1                                                   Aruba
# 2                                             Afghanistan
# 3                                                  Angola
# 4                                                 Albania
# 5                                                 Andorra
# 6                                              Arab World
# 7                                    United Arab Emirates
# 8                                               Argentina
# 9                                                 Armenia
# 10                                         American Samoa
# 11                                    Antigua and Barbuda
# 12                                              Australia
# 13                                                Austria
# 14                                             Azerbaijan
# 15                                                Burundi
# ...

# %%
fertility_df.rename(columns=
                    {'2016':'birth'},
                    inplace = True
                )
fertility_df.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4025: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   return super(DataFrame, self).rename(**kwargs)
#        Country Name      country   birth Country Code  region   lat  long
# New ID
# 1             Aruba          NaN   7.200          ABW     NaN   NaN   NaN
# 2       Afghanistan  Afghanistan  18.540          AFG    Asia  33.0  65.0
# 3            Angola       Angola  22.776          AGO  Africa -12.5  18.5
# 4           Albania      Albania   6.852          ALB  Europe  41.0  20.0
# 5           Andorra      Andorra     NaN          AND  Europe  42.5   1.6

# %%
fertility_df.rename(columns=
                    {'Country Code':'code'},
                    inplace = True
                )
fertility_df.head()
# Out:
#        Country Name      country   birth code  region   lat  long
# New ID
# 1             Aruba          NaN   7.200  ABW     NaN   NaN   NaN
# 2       Afghanistan  Afghanistan  18.540  AFG    Asia  33.0  65.0
# 3            Angola       Angola  22.776  AGO  Africa -12.5  18.5
# 4           Albania      Albania   6.852  ALB  Europe  41.0  20.0
# 5           Andorra      Andorra     NaN  AND  Europe  42.5   1.6

# %%
fertility_df.to_csv('data.csv',header=True)
