# %%
# Dependencies and Setup
import pandas as pd
import numpy as np

# File to Load 
file_to_load = "fertility_rate.csv"

# Read Purchasing File and store into Pandas data frame
fertility_data = pd.read_csv(file_to_load)
fertility_data.head()
# Out:
#   Country Name Country Code                            Indicator Name  \
# 0        Aruba          ABW  Fertility rate, total (births per woman)
# 1  Afghanistan          AFG  Fertility rate, total (births per woman)
# 2       Angola          AGO  Fertility rate, total (births per woman)
# 3      Albania          ALB  Fertility rate, total (births per woman)
# 4      Andorra          AND  Fertility rate, total (births per woman)
#
#    Indicator Code   1960   1961   1962   1963   1964   1965  ...   2007  \
# 0  SP.DYN.TFRT.IN  4.820  4.655  4.471  4.271  4.059  3.842  ...  1.763
# 1  SP.DYN.TFRT.IN  7.450  7.450  7.450  7.450  7.450  7.450  ...  6.460
# 2  SP.DYN.TFRT.IN  7.478  7.524  7.563  7.592  7.611  7.619  ...  6.368
# 3  SP.DYN.TFRT.IN  6.489  6.401  6.282  6.133  5.960  5.773  ...  1.668
# 4  SP.DYN.TFRT.IN    NaN    NaN    NaN    NaN    NaN    NaN  ...  1.180
#
#     2008   2009   2010   2011   2012   2013   2014   2015   2016
# ...

# %%
fertility_data=fertility_data.drop(['Indicator Name','Indicator Code'], axis=1)
fertility_data.head()
# Out:
#   Country Name Country Code   1960   1961   1962   1963   1964   1965   1966  \
# 0        Aruba          ABW  4.820  4.655  4.471  4.271  4.059  3.842  3.625
# 1  Afghanistan          AFG  7.450  7.450  7.450  7.450  7.450  7.450  7.450
# 2       Angola          AGO  7.478  7.524  7.563  7.592  7.611  7.619  7.618
# 3      Albania          ALB  6.489  6.401  6.282  6.133  5.960  5.773  5.581
# 4      Andorra          AND    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#     1967  ...   2007   2008   2009   2010   2011   2012   2013   2014   2015  \
# 0  3.417  ...  1.763  1.764  1.769  1.776  1.783  1.791  1.796  1.800  1.801
# 1  7.450  ...  6.460  6.254  6.038  5.816  5.595  5.380  5.174  4.981  4.802
# 2  7.613  ...  6.368  6.307  6.238  6.162  6.082  6.000  5.920  5.841  5.766
# 3  5.394  ...  1.668  1.650  1.646  1.653  1.668  1.685  1.700  1.710  1.714
# 4    NaN  ...  1.180  1.250  1.190  1.270    NaN    NaN    NaN    NaN    NaN
#
#     2016
# 0  1.800
# 1  4.635
# ...

# %%
# File to Load 
file_to_load = "country_lat_long.csv"

# Read Purchasing File and store into Pandas data frame
country_data = pd.read_csv(file_to_load, encoding='cp1252')
country_data.head()
# Out:
#   country   latitude  longitude                  name
# 0      AD  42.546245   1.601554               Andorra
# 1      AE  23.424076  53.847818  United Arab Emirates
# 2      AF  33.939110  67.709953           Afghanistan
# 3      AG  17.060816 -61.796428   Antigua and Barbuda
# 4      AI  18.220554 -63.068615              Anguilla

# %%
country_data.rename(columns=
                    {'name':'Country Name'},
                    inplace = True
                )
country_data.head()
# Out:
#   country   latitude  longitude          Country Name
# 0      AD  42.546245   1.601554               Andorra
# 1      AE  23.424076  53.847818  United Arab Emirates
# 2      AF  33.939110  67.709953           Afghanistan
# 3      AG  17.060816 -61.796428   Antigua and Barbuda
# 4      AI  18.220554 -63.068615              Anguilla

# %%
fertility_country = pd.merge(left=fertility_data,right=country_data, how='left', left_on='Country Name', right_on='Country Name')
fertility_country.head()
# Out:
#   Country Name Country Code   1960   1961   1962   1963   1964   1965   1966  \
# 0        Aruba          ABW  4.820  4.655  4.471  4.271  4.059  3.842  3.625
# 1  Afghanistan          AFG  7.450  7.450  7.450  7.450  7.450  7.450  7.450
# 2       Angola          AGO  7.478  7.524  7.563  7.592  7.611  7.619  7.618
# 3      Albania          ALB  6.489  6.401  6.282  6.133  5.960  5.773  5.581
# 4      Andorra          AND    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#     1967  ...   2010   2011   2012   2013   2014   2015   2016  country  \
# 0  3.417  ...  1.776  1.783  1.791  1.796  1.800  1.801  1.800       AW
# 1  7.450  ...  5.816  5.595  5.380  5.174  4.981  4.802  4.635       AF
# 2  7.613  ...  6.162  6.082  6.000  5.920  5.841  5.766  5.694       AO
# 3  5.394  ...  1.653  1.668  1.685  1.700  1.710  1.714  1.713       AL
# 4    NaN  ...  1.270    NaN    NaN    NaN    NaN    NaN    NaN       AD
#
#     latitude  longitude
# 0  12.521110 -69.968338
# ...

# %%
fertility_country.dropna(axis=0, how='any')
# Out:
#                  Country Name Country Code   1960   1961   1962   1963   1964  \
# 0                       Aruba          ABW  4.820  4.655  4.471  4.271  4.059
# 1                 Afghanistan          AFG  7.450  7.450  7.450  7.450  7.450
# 2                      Angola          AGO  7.478  7.524  7.563  7.592  7.611
# 3                     Albania          ALB  6.489  6.401  6.282  6.133  5.960
# 6        United Arab Emirates          ARE  6.929  6.910  6.892  6.875  6.857
# 7                   Argentina          ARG  3.109  3.100  3.089  3.078  3.068
# 8                     Armenia          ARM  4.786  4.670  4.521  4.345  4.150
# 10        Antigua and Barbuda          ATG  4.425  4.386  4.344  4.299  4.250
# 11                  Australia          AUS  3.453  3.540  3.442  3.332  3.146
# 12                    Austria          AUT  2.690  2.780  2.800  2.820  2.790
# 13                 Azerbaijan          AZE  5.878  5.937  5.961  5.945  5.888
# ...

# %%
# File to Load 
file_to_load = "country_continent.csv"

# Read Purchasing File and store into Pandas data frame
region_data = pd.read_csv(file_to_load)
region_data.head()
# Out:
#      Country Name   region
# 0     Afghanistan     Asia
# 1   Åland Islands   Europe
# 2         Albania   Europe
# 3         Algeria   Africa
# 4  American Samoa  Oceania

# %%
fertility_country_region = pd.merge(left=fertility_country,right=region_data, how='left', left_on='Country Name', right_on='Country Name')
fertility_country_region.head()
# Out:
#   Country Name Country Code   1960   1961   1962   1963   1964   1965   1966  \
# 0        Aruba          ABW  4.820  4.655  4.471  4.271  4.059  3.842  3.625
# 1  Afghanistan          AFG  7.450  7.450  7.450  7.450  7.450  7.450  7.450
# 2       Angola          AGO  7.478  7.524  7.563  7.592  7.611  7.619  7.618
# 3      Albania          ALB  6.489  6.401  6.282  6.133  5.960  5.773  5.581
# 4      Andorra          AND    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
#     1967  ...   2011   2012   2013   2014   2015   2016  country   latitude  \
# 0  3.417  ...  1.783  1.791  1.796  1.800  1.801  1.800       AW  12.521110
# 1  7.450  ...  5.595  5.380  5.174  4.981  4.802  4.635       AF  33.939110
# 2  7.613  ...  6.082  6.000  5.920  5.841  5.766  5.694       AO -11.202692
# 3  5.394  ...  1.668  1.685  1.700  1.710  1.714  1.713       AL  41.153332
# 4    NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN       AD  42.546245
#
#    longitude         region
# ...

# %%
fertility_df=fertility_country_region[['Country Name','2016','Country Code','region','latitude','longitude']]
fertility_df.head()
# Out:
#   Country Name   2016 Country Code         region   latitude  longitude
# 0        Aruba  1.800          ABW  North America  12.521110 -69.968338
# 1  Afghanistan  4.635          AFG           Asia  33.939110  67.709953
# 2       Angola  5.694          AGO         Africa -11.202692  17.873887
# 3      Albania  1.713          ALB         Europe  41.153332  20.168331
# 4      Andorra    NaN          AND         Europe  42.546245   1.601554

# %%
fertility_df.dropna(axis=0, how='any')
fertility_df.head()
# Out:
#   Country Name   2016 Country Code         region   latitude  longitude
# 0        Aruba  1.800          ABW  North America  12.521110 -69.968338
# 1  Afghanistan  4.635          AFG           Asia  33.939110  67.709953
# 2       Angola  5.694          AGO         Africa -11.202692  17.873887
# 3      Albania  1.713          ALB         Europe  41.153332  20.168331
# 4      Andorra    NaN          AND         Europe  42.546245   1.601554

# %%
fertility_df.index = np.arange(1, len(fertility_df) + 1)
fertility_df.head()
# Out:
#   Country Name   2016 Country Code         region   latitude  longitude
# 1        Aruba  1.800          ABW  North America  12.521110 -69.968338
# 2  Afghanistan  4.635          AFG           Asia  33.939110  67.709953
# 3       Angola  5.694          AGO         Africa -11.202692  17.873887
# 4      Albania  1.713          ALB         Europe  41.153332  20.168331
# 5      Andorra    NaN          AND         Europe  42.546245   1.601554

# %%
fertility_df.index.name = 'id'
fertility_df.head()
# Out:
#    Country Name   2016 Country Code         region   latitude  longitude
# id
# 1         Aruba  1.800          ABW  North America  12.521110 -69.968338
# 2   Afghanistan  4.635          AFG           Asia  33.939110  67.709953
# 3        Angola  5.694          AGO         Africa -11.202692  17.873887
# 4       Albania  1.713          ALB         Europe  41.153332  20.168331
# 5       Andorra    NaN          AND         Europe  42.546245   1.601554

# %%
fertility_df.rename(columns=
                    {'Country Name':'country'},
                    inplace = True
                )
fertility_df.head()
# Out:
#         country   2016 Country Code         region   latitude  longitude
# id
# 1         Aruba  1.800          ABW  North America  12.521110 -69.968338
# 2   Afghanistan  4.635          AFG           Asia  33.939110  67.709953
# 3        Angola  5.694          AGO         Africa -11.202692  17.873887
# 4       Albania  1.713          ALB         Europe  41.153332  20.168331
# 5       Andorra    NaN          AND         Europe  42.546245   1.601554

# %%
fertility_df.rename(columns=
                    {'2016':'birth'},
                    inplace = True
                )
fertility_df.head()
# Out:
#         country  birth Country Code         region   latitude  longitude
# id
# 1         Aruba  1.800          ABW  North America  12.521110 -69.968338
# 2   Afghanistan  4.635          AFG           Asia  33.939110  67.709953
# 3        Angola  5.694          AGO         Africa -11.202692  17.873887
# 4       Albania  1.713          ALB         Europe  41.153332  20.168331
# 5       Andorra    NaN          AND         Europe  42.546245   1.601554

# %%
fertility_df.rename(columns=
                    {'Country Code':'code'},
                    inplace = True
                )
fertility_df.head()
# Out:
#         country  birth code         region   latitude  longitude
# id
# 1         Aruba  1.800  ABW  North America  12.521110 -69.968338
# 2   Afghanistan  4.635  AFG           Asia  33.939110  67.709953
# 3        Angola  5.694  AGO         Africa -11.202692  17.873887
# 4       Albania  1.713  ALB         Europe  41.153332  20.168331
# 5       Andorra    NaN  AND         Europe  42.546245   1.601554

# %%
fertility_df.rename(columns=
                    {'latitude':'lat'},
                    inplace = True
                )
fertility_df.head()
# Out:
#         country  birth code         region        lat  longitude
# id
# 1         Aruba  1.800  ABW  North America  12.521110 -69.968338
# 2   Afghanistan  4.635  AFG           Asia  33.939110  67.709953
# 3        Angola  5.694  AGO         Africa -11.202692  17.873887
# 4       Albania  1.713  ALB         Europe  41.153332  20.168331
# 5       Andorra    NaN  AND         Europe  42.546245   1.601554

# %%
fertility_df.rename(columns=
                    {'longitude':'long'},
                    inplace = True
                )
fertility_df.head()
# Out:
#         country  birth code         region        lat       long
# id
# 1         Aruba  1.800  ABW  North America  12.521110 -69.968338
# 2   Afghanistan  4.635  AFG           Asia  33.939110  67.709953
# 3        Angola  5.694  AGO         Africa -11.202692  17.873887
# 4       Albania  1.713  ALB         Europe  41.153332  20.168331
# 5       Andorra    NaN  AND         Europe  42.546245   1.601554

# %%
fertility_df.dropna(axis=0, how='any')
fertility_df.head()
# Out:
#         country  birth code         region        lat       long
# id
# 1         Aruba  1.800  ABW  North America  12.521110 -69.968338
# 2   Afghanistan  4.635  AFG           Asia  33.939110  67.709953
# 3        Angola  5.694  AGO         Africa -11.202692  17.873887
# 4       Albania  1.713  ALB         Europe  41.153332  20.168331
# 5       Andorra    NaN  AND         Europe  42.546245   1.601554

# %%
fertility_df.loc[:,'birth'] *= 4 
fertility_df.head()
# Out:
#         country   birth code         region        lat       long
# id
# 1         Aruba   7.200  ABW  North America  12.521110 -69.968338
# 2   Afghanistan  18.540  AFG           Asia  33.939110  67.709953
# 3        Angola  22.776  AGO         Africa -11.202692  17.873887
# 4       Albania   6.852  ALB         Europe  41.153332  20.168331
# 5       Andorra     NaN  AND         Europe  42.546245   1.601554

# %%
fertility_df.to_csv('data.csv',header=True)
